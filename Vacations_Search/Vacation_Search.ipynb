# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config_2 import geo_api_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv('../Weather_Database/WeatherPy_Database')

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0         Kapaa      US  22.0752 -159.3190     75.52        87
# 1        1  Punta Arenas      CL -53.1500  -70.9167     42.91        70
# 2        2       Yeppoon      AU -23.1333  150.7333     83.98        71
# 3        3    Priiskovyy      RU  51.9333  116.6333     57.33        41
# 4        4        Castro      BR -24.7911  -50.0119     61.57        93
#
#    Cloudiness  Wind Speed Current Descriptions
# 0          40        6.91     scattered clouds
# 1          40       17.27     scattered clouds
# 2          39        9.51     scattered clouds
# 3           7       12.71            clear sky
# 4          55        1.72        broken clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature: "))
max_temp = float(input("What is the maximum temperature: "))

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]

# Display sample data
preferred_cities_df
# Out:
#      City_ID       City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0      Kapaa      US  22.0752 -159.3190     75.52        87
# 2          2    Yeppoon      AU -23.1333  150.7333     83.98        71
# 4          4     Castro      BR -24.7911  -50.0119     61.57        93
# 5          5    Isangel      VU -19.5500  169.2667     84.31        84
# 7          7  Busselton      AU -33.6500  115.3333     61.41        86
# ..       ...        ...     ...      ...       ...       ...       ...
# 717      717   Belmonte      BR -15.8631  -38.8828     74.98        80
# 718      718      Jatai      BR -17.8814  -51.7144     67.77        79
# 719      719      Babai      IN  22.7000   77.9333     88.47        31
# 720      720   Itaituba      BR  -4.2761  -55.9836     70.93       100
# 722      722    Ardakan      IR  32.3100   54.0175     77.34        12
#
#      Cloudiness  Wind Speed Current Descriptions
# 0            40        6.91     scattered clouds
# 2            39        9.51     scattered clouds
# 4            55        1.72        broken clouds
# 5            75        0.00        broken clouds
# 7           100       16.37      overcast clouds
# ..          ...         ...                  ...
# 717          29        1.74     scattered clouds
# 718          49        2.77     scattered clouds
# 719          99        5.30      overcast clouds
# 720          96        1.77      overcast clouds
# 722          79        7.05        broken clouds
#
# [396 rows x 10 columns]

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df = preferred_cities_df.dropna()

# Display sample data
preferred_cities_df
# Out:
#      City_ID       City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0      Kapaa      US  22.0752 -159.3190     75.52        87
# 2          2    Yeppoon      AU -23.1333  150.7333     83.98        71
# 4          4     Castro      BR -24.7911  -50.0119     61.57        93
# 5          5    Isangel      VU -19.5500  169.2667     84.31        84
# 7          7  Busselton      AU -33.6500  115.3333     61.41        86
# ..       ...        ...     ...      ...       ...       ...       ...
# 717      717   Belmonte      BR -15.8631  -38.8828     74.98        80
# 718      718      Jatai      BR -17.8814  -51.7144     67.77        79
# 719      719      Babai      IN  22.7000   77.9333     88.47        31
# 720      720   Itaituba      BR  -4.2761  -55.9836     70.93       100
# 722      722    Ardakan      IR  32.3100   54.0175     77.34        12
#
#      Cloudiness  Wind Speed Current Descriptions
# 0            40        6.91     scattered clouds
# 2            39        9.51     scattered clouds
# 4            55        1.72        broken clouds
# 5            75        0.00        broken clouds
# 7           100       16.37      overcast clouds
# ..          ...         ...                  ...
# 717          29        1.74     scattered clouds
# 718          49        2.77     scattered clouds
# 719          99        5.30      overcast clouds
# 720          96        1.77      overcast clouds
# 722          79        7.05        broken clouds
#
# [390 rows x 10 columns]

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp","Current Descriptions", "Lat", "Lng"]].copy()
# Create a new column "Hotel Name".
hotel_df["Hotel_Name"] = ""
hotel_df
# Out:
#           City Country  Max Temp Current Descriptions      Lat       Lng  \
# 0        Kapaa      US     75.52     scattered clouds  22.0752 -159.3190
# 2      Yeppoon      AU     83.98     scattered clouds -23.1333  150.7333
# 4       Castro      BR     61.57        broken clouds -24.7911  -50.0119
# 5      Isangel      VU     84.31        broken clouds -19.5500  169.2667
# 7    Busselton      AU     61.41      overcast clouds -33.6500  115.3333
# ..         ...     ...       ...                  ...      ...       ...
# 717   Belmonte      BR     74.98     scattered clouds -15.8631  -38.8828
# 718      Jatai      BR     67.77     scattered clouds -17.8814  -51.7144
# 719      Babai      IN     88.47      overcast clouds  22.7000   77.9333
# 720   Itaituba      BR     70.93      overcast clouds  -4.2761  -55.9836
# 722    Ardakan      IR     77.34        broken clouds  32.3100   54.0175
#
#     Hotel_Name
# 0
# 2
# 4
# 5
# 7
# ..         ...
# 717
# 718
# 719
# 720
# 722
#
# [390 rows x 7 columns]

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geo_api_key,
    "limit":10
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params).json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel_Name"] = name_address['features'][0]['properties']['name']
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel_Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel_Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Kapaa - nearest hotel: Pono Kai Resort
# Yeppoon - nearest hotel: Blossom's on Seaspray
# Castro - nearest hotel: Hotel Central Palace
# Isangel - nearest hotel: Tanna Lodge
# Busselton - nearest hotel: No hotel found
# Nshamba - nearest hotel: No hotel found
# Pilikwe - nearest hotel: No hotel found
# Yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# Avarua - nearest hotel: Paradise Inn
# Imbituba - nearest hotel: Silvestre Praia Hotel
# Atuona - nearest hotel: Pearl Resort
# Hilo - nearest hotel: Dolphin Bay Hotel
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Ponta Do Sol - nearest hotel: Estalagem Ponta do Sol
# Vaini - nearest hotel: Keleti International Resort
# Ewa Beach - nearest hotel: Hampton Inn & Suites Oahu/Kapolei
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Ribeira Grande - nearest hotel: No hotel found
# Kailua - nearest hotel: No hotel found
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Port Elizabeth - nearest hotel: Waterford Hotel
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Bengkulu - nearest hotel: Dena Hotel
# Ponta Delgada - nearest hotel: Hotel Talisman
# Sigli - nearest hotel: No hotel found
# Resistencia - nearest hotel: Residencial Bariloche
# Grand Gaube - nearest hotel: Coco Villa
# Iralaya - nearest hotel: No hotel found
# Carnarvon - nearest hotel: No hotel found
# Itapirapua - nearest hotel: No hotel found
# Georgetown - nearest hotel: Page 63 hostel
# Moranbah - nearest hotel: No hotel found
# Quatre Cocos - nearest hotel: Horisun
# Tocopilla - nearest hotel: hotel Isidora
# Emerald - nearest hotel: Emerald Central Hotel
# Chabahar - nearest hotel: هتل سپیده
# Meulaboh - nearest hotel: Hotel Meuligou
# Am Timan - nearest hotel: Nimla
# Labelle - nearest hotel: No hotel found
# Sasaima - nearest hotel: Centro Vacacional La Maria
# Gualaquiza - nearest hotel: Hotel Internacional
# Caravelas - nearest hotel: Pousada dos Navegantes
# Axim - nearest hotel: Axim Beach Hotel
# Kavaratti - nearest hotel: No hotel found
# Saint-Philippe - nearest hotel: Le Baril
# Vila Franca Do Campo - nearest hotel: Vinha d'Areia Beach Hotel
# Ahipara - nearest hotel: YHA Ahipara
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Sao Filipe - nearest hotel: Bela Vista
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Cape Town - nearest hotel: Townhouse Hotel
# Sola - nearest hotel: No hotel found
# Dubbo - nearest hotel: Blue Gum Motel
# Arraial Do Cabo - nearest hotel: No hotel found
# Zhanakorgan - nearest hotel: No hotel found
# Mahebourg - nearest hotel: Grand Bel Air
# Uvira - nearest hotel: Batiment Kasangala
# Geraldton - nearest hotel: Ocean Centre Hotel
# Guhagar - nearest hotel: Prestige Deluxe
# Port Alfred - nearest hotel: No hotel found
# Los Llanos De Aridane - nearest hotel: Valle Aridane
# Jardim - nearest hotel: Hotel Uchôa
# Sao Joaquim Do Monte - nearest hotel: No hotel found
# Singarayakonda - nearest hotel: No hotel found
# East London - nearest hotel: No hotel found
# Sosua - nearest hotel: Casa Marina Beach & Reef
# Coahuayana - nearest hotel: No hotel found
# Santa Marta - nearest hotel: Casa Mita
# San Pedro - nearest hotel: Hotel Takara
# Colares - nearest hotel: Hotel Arribas
# Quevedo - nearest hotel: Hotel Chifa "JADE"
# Cidreira - nearest hotel: Hotel Castelo
# Bambous Virieux - nearest hotel: No hotel found
# Udgir - nearest hotel: No hotel found
# Nanchong - nearest hotel: 北湖宾馆
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Airai - nearest hotel: No hotel found
# Macenta - nearest hotel: Hôtel Macenta
# Sinnamary - nearest hotel: Hôtel du fleuve
# Nobeoka - nearest hotel: 延岡アーバンホテル
# Shache - nearest hotel: 莎車新盛賓舘
# Esperance - nearest hotel: Hospitality
# Brownwood - nearest hotel: Hampton Inn Brownwood
# Vega De Alatorre - nearest hotel: No hotel found
# Tawau - nearest hotel: Eden boutique
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Zaraza - nearest hotel: No hotel found
# San Cristobal - nearest hotel: Terra Sur
# Nouadhibou - nearest hotel: Hotel valencia
# Santa Isabel Do Rio Negro - nearest hotel: Hotel Maikon
# Cockburn Town - nearest hotel: The Salt Raker Inn
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Shunyi - nearest hotel: 会议楼
# Ndele - nearest hotel: No hotel found
# Curup - nearest hotel: Berkah syariah
# Butaritari - nearest hotel: No hotel found
# Phan Thiet - nearest hotel: Khách sạn Cà Ty
# Dingle - nearest hotel: No hotel found
# Hithadhoo - nearest hotel: Pebbles Inn
# Lichinga - nearest hotel: Residencial 2+1
# Hokitika - nearest hotel: Beachfront Hotel
# Santa Vitoria Do Palmar - nearest hotel: Hotel Brasil
# Vao - nearest hotel: Nataiwatch
# Kijang - nearest hotel: No hotel found
# Chuy - nearest hotel: Alerces
# Ziro - nearest hotel: No hotel found
# Hasaki - nearest hotel: 大新旅館
# Bac Lieu - nearest hotel: Khách sạn Bạc Liêu
# Say - nearest hotel: No hotel found
# Kyra - nearest hotel: No hotel found
# Marawi - nearest hotel: Marawi Resort Hotel
# Peniche - nearest hotel: Residencial Maciel
# Noumea - nearest hotel: Hotel Gondwana
# Amapa - nearest hotel: No hotel found
# Takoradi - nearest hotel: Hillcrest
# Korla - nearest hotel: Silver Star Hotel
# Daru - nearest hotel: Kuki
# Tessalit - nearest hotel: No hotel found
# Mankera - nearest hotel: No hotel found
# Mahanoro - nearest hotel: Vanilla Bungalow
# Buzmeyin - nearest hotel: Myhmanhana
# Bara - nearest hotel: No hotel found
# Faanui - nearest hotel: Oa Oa Lodge
# Rabo De Peixe - nearest hotel: Pico do Refugio
# Sheopur - nearest hotel: No hotel found
# Ozu - nearest hotel: No hotel found
# Lata - nearest hotel: No hotel found
# Mwinilunga - nearest hotel: No hotel found
# Barao De Melgaco - nearest hotel: No hotel found
# Chake Chake - nearest hotel: Annex Pemba Hotel
# Souillac - nearest hotel: Hotel SkylineInn
# Luganville - nearest hotel: Beachfront Resort
# Port Augusta - nearest hotel: Hotel Commonwealth
# Sri Aman - nearest hotel: Mega Inn
# Saint-Pierre - nearest hotel: Tropic Hotel
# Sur - nearest hotel: Sur Hotel
# Kahului - nearest hotel: Maui Seaside Hotel
# Rio Branco - nearest hotel: No hotel found
# Taicheng - nearest hotel: No hotel found
# Adrar - nearest hotel: No hotel found
# Concepcion Del Oro - nearest hotel: No hotel found
# Moron - nearest hotel: La Esquina
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Cabedelo - nearest hotel: No hotel found
# Saint-Georges - nearest hotel: Deyna's City Inn
# Quijingue - nearest hotel: No hotel found
# Kavieng - nearest hotel: Kavieng Hotel
# Riyadh - nearest hotel: White Palace Hotel
# Baoro - nearest hotel: No hotel found
# Pitimbu - nearest hotel: Pousada Brisa Mar
# Montepuez - nearest hotel: Complexo Messalo
# Acapulco - nearest hotel: Hotel del Valle
# Sabang - nearest hotel: Sabang Hill
# Poum - nearest hotel: No hotel found
# Huaura - nearest hotel: Hotel Mi Choacan
# Camargo - nearest hotel: Hotel Santa Fe
# Palm Valley - nearest hotel: Sawgrass Marriott Golf Resort & Spa
# Ankazoabo - nearest hotel: No hotel found
# Sangmelima - nearest hotel: Hôtel l'Afamba
# Yining - nearest hotel: No hotel found
# Le Francois - nearest hotel: Hôtel la Frégate Bleu
# Hazorasp - nearest hotel: No hotel found
# Gourcy - nearest hotel: Hôtel Cité Sàrl
# Victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# Aksu - nearest hotel: Akesu Tianyuan International Hotel
# Tevaitoa - nearest hotel: Chambre d'hote
# Semnan - nearest hotel: مرکز آموزشی رفاهی فرهنگیان - خانه معلم
# Garissa - nearest hotel: Hiddig Hotel
# Muyuka - nearest hotel: No hotel found
# Kampot - nearest hotel: Sambor Sambat Guesthouse
# Shenzhen - nearest hotel: Shenzhen International Elite Hotel
# Byron Bay - nearest hotel: Lord Byron Resort
# Maragogi - nearest hotel: Pousada Mariluz
# Wollongong - nearest hotel: Sage Hotel Wollongong
# Neijiang - nearest hotel: No hotel found
# Tautira - nearest hotel: No hotel found
# Yuncheng - nearest hotel: 运城宾馆
# Flinders - nearest hotel: No hotel found
# Bela - nearest hotel: Hotel City Palace
# Biak - nearest hotel: No hotel found
# San Patricio - nearest hotel: No hotel found
# Kloulklubed - nearest hotel: The Adventures Inn
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Pombas - nearest hotel: Aldeia Jerome
# San Andres - nearest hotel: Hotel Decameron Isleño
# Menongue - nearest hotel: No hotel found
# Umm Lajj - nearest hotel: No hotel found
# Ternate - nearest hotel: Boulivard ternate
# Marzuq - nearest hotel: No hotel found
# Varadero - nearest hotel: Hotel Cuatro Palmas
# Lakatoro - nearest hotel: No hotel found
# Zhuhai - nearest hotel: No hotel found
# Aswan - nearest hotel: Yaseen hotel
# Danjiangkou - nearest hotel: No hotel found
# Seddon - nearest hotel: Palms Hotel
# Mazatlan - nearest hotel: Mona Inn
# Vilhena - nearest hotel: No hotel found
# Komsomolskiy - nearest hotel: Hotel "Ikat House"
# Kasane - nearest hotel: Kasane Travel Lodge
# Praia Da Vitoria - nearest hotel: Salles
# Ballina - nearest hotel: Ballina Beach Resort
# Boca Do Acre - nearest hotel: No hotel found
# Yaan - nearest hotel: No hotel found
# Paranavai - nearest hotel: Pensão Padre Cícero,
# Bambanglipuro - nearest hotel: No hotel found
# Kirakira - nearest hotel: No hotel found
# Naze - nearest hotel: ビジネス旅館畠山
# Lere - nearest hotel: No hotel found
# Port Moresby - nearest hotel: The Sanctuary Hotel and Spa
# Gizo - nearest hotel: Gizo Hotel
# Kouango - nearest hotel: No hotel found
# Gorontalo - nearest hotel: Grand City Hotel
# Poli - nearest hotel: Imful
# Fare - nearest hotel: hôtel Maitai Lapita Village
# Bontang - nearest hotel: Hotel Sederhana
# Pisco - nearest hotel: La Portada
# Cairns - nearest hotel: Cairns Queens Court Accommodation
# Simpang - nearest hotel: No hotel found
# Nisia Floresta - nearest hotel: No hotel found
# Fengzhen - nearest hotel: 春江大酒店
# Kibala - nearest hotel: No hotel found
# Codajas - nearest hotel: No hotel found
# Asmara - nearest hotel: Crystal Hotel فندق كريستال
# Lengshuitan - nearest hotel: No hotel found
# Paoua - nearest hotel: No hotel found
# Araouane - nearest hotel: No hotel found
# Mandawar - nearest hotel: No hotel found
# Olinda - nearest hotel: Fidji Motel
# Sorong - nearest hotel: Hotel Membramo Marina
# Hami - nearest hotel: No hotel found
# Huarmey - nearest hotel: Hostal Santa Rosa
# Bathsheba - nearest hotel: Atlantis Hotel
# Pokhara - nearest hotel: Hotel Annapurna View Sarangkot
# Cartagena Del Chaira - nearest hotel: Los Corceles
# Atar - nearest hotel: فندق سكليل
# Grenfell - nearest hotel: Albion Hotel
# The Valley - nearest hotel: CeBlue
# Mopipi - nearest hotel: No hotel found
# Ibra - nearest hotel: الدكيك
# Ubauro - nearest hotel: No hotel found
# Harper - nearest hotel: No hotel found
# Sompeta - nearest hotel: No hotel found
# Salalah - nearest hotel: Muscat International Hotel
# Nyanza - nearest hotel: New Life Motel
# Dubti - nearest hotel: No hotel found
# Mathathane - nearest hotel: No hotel found
# Bhubaneswar - nearest hotel: Airport Park Villa
# Kiama - nearest hotel: Nova Kiama
# Baruun-Urt - nearest hotel: No hotel found
# Vaitape - nearest hotel: Oa Oa Lodge
# Tecoanapa - nearest hotel: No hotel found
# Eyl - nearest hotel: فندق ايل دابي
# Vanimo - nearest hotel: CBC Guesthouse
# Taltal - nearest hotel: Hostería Taltal
# Labuan - nearest hotel: Labuan Avenue Hotel
# Lavumisa - nearest hotel: No hotel found
# Huanren - nearest hotel: No hotel found
# Roebourne - nearest hotel: No hotel found
# Ambilobe - nearest hotel: Hôtel National
# Nador - nearest hotel: Hotel Lixus
# Pimenta Bueno - nearest hotel: Cristalina palace hotel
# Bulungu - nearest hotel: No hotel found
# Farah - nearest hotel: No hotel found
# Tual - nearest hotel: Suita
# Rafiganj - nearest hotel: No hotel found
# Santiago Del Estero - nearest hotel: Nuevo Hotel Brístol
# San Miguel - nearest hotel: Continental Plaza Hotel
# Palauig - nearest hotel: No hotel found
# Jaisalmer - nearest hotel: Jeet Mahal
# Chaparral - nearest hotel: Europa
# Hirara - nearest hotel: 古謝そば屋
# Khorramshahr - nearest hotel: بيت صباح التميمي
# Sambava - nearest hotel: Royal Sava Hôtel
# Inirida - nearest hotel: Residencias El Turista del Guainia
# Great Bend - nearest hotel: Best Western
# Faya - nearest hotel: No hotel found
# Cleburne - nearest hotel: Liberty Hotel
# Puerto Carreno - nearest hotel: Carreño Plaza
# Xam Nua - nearest hotel: Phetmeuangsam Hotel
# Linhares - nearest hotel: Days Inn Linhares
# Singaraja - nearest hotel: Hotel Sentral
# Wanaka - nearest hotel: No hotel found
# Jiuquan - nearest hotel: 民族宾馆
# Bubaque - nearest hotel: Chez Julio
# Jiaocheng - nearest hotel: 蕉岭迎宾馆
# Maun - nearest hotel: Center Lodge Conference Center
# Ewo - nearest hotel: No hotel found
# Carutapera - nearest hotel: No hotel found
# Abu Dhabi - nearest hotel: Marriott Downtown Abu-Dhabi
# Nishihara - nearest hotel: ユインチホテル南城
# Port Hedland - nearest hotel: The Esplanade Hotel
# Mayumba - nearest hotel: Résidence Hôtelière Fabso
# Atambua - nearest hotel: Hotel Matahari
# Vinh - nearest hotel: Sai gon Kim Lien
# Pompeu - nearest hotel: No hotel found
# Aripuana - nearest hotel: No hotel found
# Gewane - nearest hotel: No hotel found
# Dzilam Gonzalez - nearest hotel: No hotel found
# Tuy Hoa - nearest hotel: Vinh Tuan Hotel
# Porto Novo - nearest hotel: Hôtel 6500 CFA
# Tura - nearest hotel: No hotel found
# Tuensang - nearest hotel: No hotel found
# Omboue - nearest hotel: Hôtel Georges Faustin Aurat
# Lucea - nearest hotel: Blue Paloma Bed And Breakfast
# Kutum - nearest hotel: No hotel found
# Ambovombe - nearest hotel: La source
# Auki - nearest hotel: No hotel found
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Ellisras - nearest hotel: GPS Hotel
# Tarakan - nearest hotel: Hotel Dynasty
# Bam - nearest hotel: هتل جهانگردی بم
# Ibipeba - nearest hotel: No hotel found
# Port Saint Lucie - nearest hotel: Best Western Port Saint Lucie Building 2
# Yuanping - nearest hotel: No hotel found
# Kaputa - nearest hotel: No hotel found
# Rey Bouba - nearest hotel: No hotel found
# Grand-Santi - nearest hotel: No hotel found
# Ixtapa - nearest hotel: No hotel found
# Malpe - nearest hotel: Hotel Kart
# Loandjili - nearest hotel: Le Raphia Guest House
# Pabna - nearest hotel: Hotel Balaka
# Micheweni - nearest hotel: No hotel found
# Padang - nearest hotel: losmen Surya
# Touros - nearest hotel: Pousada Atlântico
# Meiganga - nearest hotel: No hotel found
# Akyab - nearest hotel: Yuzana Aung Motel 1
# Gladstone - nearest hotel: Gladstone Downtown Central
# Umm Kaddadah - nearest hotel: No hotel found
# Minab - nearest hotel: هتل صدف
# Denpasar - nearest hotel: Hotel Candra Adiguna
# Rabak - nearest hotel: No hotel found
# Fukue - nearest hotel: 五島第一ホテル
# Sawakin - nearest hotel: Hotel Halfa
# Nsunga - nearest hotel: No hotel found
# Akdepe - nearest hotel: No hotel found
# Ippy - nearest hotel: No hotel found
# Lima - nearest hotel: Hotel Peach Garden
# Luba - nearest hotel: Hotel Jones
# Kagoro - nearest hotel: No hotel found
# Marovoay - nearest hotel: No hotel found
# Karratha - nearest hotel: Karratha International Hotel
# Mana - nearest hotel: Le Samana
# Waddan - nearest hotel: No hotel found
# Coruripe - nearest hotel: No hotel found
# Crixas - nearest hotel: No hotel found
# Sampang - nearest hotel: Hotel Trunojoyo (PKPRI)
# Luanda - nearest hotel: Hotel Forum
# Gatton - nearest hotel: Royal Hotel
# Honiara - nearest hotel: King Solomon Hotel
# Quelimane - nearest hotel: Mabassa
# Lajas - nearest hotel: Hotel y Parador Oasis
# Kaeo - nearest hotel: No hotel found
# Namatanai - nearest hotel: Namatanai Hotel
# Wellington - nearest hotel: Travelodge
# Alyangula - nearest hotel: No hotel found
# Port Lincoln - nearest hotel: Boston Hotel
# Manoel Urbano - nearest hotel: No hotel found
# Esmeraldas - nearest hotel: No hotel found
# Shimoni - nearest hotel: Shimoni Reef Lodge
# Kudahuvadhoo - nearest hotel: No hotel found
# Port Macquarie - nearest hotel: The Observatory
# Pouembout - nearest hotel: No hotel found
# Kiomboi - nearest hotel: No hotel found
# Hirata - nearest hotel: ひらたメイプルホテル
# Soto La Marina - nearest hotel: Arellano
# Middelburg - nearest hotel: No hotel found
# Buin - nearest hotel: No hotel found
# Champerico - nearest hotel: Hotel y Restaurante El Submarino
# San Policarpo - nearest hotel: No hotel found
# Pochutla - nearest hotel: Posada San Jose
# Santa Rosa - nearest hotel: JARS RESORT
# Moyale - nearest hotel: Nicest
# Mbanza-Ngungu - nearest hotel: auberge la rose
# Kokopo - nearest hotel: Hotel Kokopo
# Parrita - nearest hotel: Hotel Paraíso Carlisa
# Tamandare - nearest hotel: Pousada Baia dos Corais
# Old Shinyanga - nearest hotel: No hotel found
# Ninghai - nearest hotel: Xin Nian Xi Hotel
# Veraval - nearest hotel: Shyam
# Matara - nearest hotel: Villa Palm Breeze
# Rio Verde De Mato Grosso - nearest hotel: No hotel found
# Jishou - nearest hotel: JinHuang Hotel
# Oyama - nearest hotel: 東横イン 小山駅東口1
# Rivadavia - nearest hotel: Hotel Pasambay
# Hatillo - nearest hotel: No hotel found
# Belmonte - nearest hotel: No hotel found
# Jatai - nearest hotel: Hotel Rio Claro
# Babai - nearest hotel: osho ashram
# Itaituba - nearest hotel: TG Hotel
# Ardakan - nearest hotel: هتل رستوران باغ سرای اردکان
#           City Country  Max Temp Current Descriptions      Lat       Lng  \
# 0        Kapaa      US     75.52     scattered clouds  22.0752 -159.3190
# 2      Yeppoon      AU     83.98     scattered clouds -23.1333  150.7333
# 4       Castro      BR     61.57        broken clouds -24.7911  -50.0119
# 5      Isangel      VU     84.31        broken clouds -19.5500  169.2667
# 7    Busselton      AU     61.41      overcast clouds -33.6500  115.3333
# ..         ...     ...       ...                  ...      ...       ...
# 717   Belmonte      BR     74.98     scattered clouds -15.8631  -38.8828
# 718      Jatai      BR     67.77     scattered clouds -17.8814  -51.7144
# 719      Babai      IN     88.47      overcast clouds  22.7000   77.9333
# 720   Itaituba      BR     70.93      overcast clouds  -4.2761  -55.9836
# 722    Ardakan      IR     77.34        broken clouds  32.3100   54.0175
#
#                       Hotel_Name
# 0                Pono Kai Resort
# 2          Blossom's on Seaspray
# 4           Hotel Central Palace
# 5                    Tanna Lodge
# 7                 No hotel found
# ..                           ...
# 717               No hotel found
# 718              Hotel Rio Claro
# 719                  osho ashram
# 720                     TG Hotel
# 722  هتل رستوران باغ سرای اردکان
#
# [390 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
hotel_df.dtypes
# Out:
# City                     object
# Country                  object
# Max Temp                float64
# Current Descriptions     object
# Lat                     float64
# Lng                     float64
# Hotel_Name               object
# dtype: object

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.query("Hotel_Name != 'No hotel found'")

# Display sample data
clean_hotel_df
# Out:
#           City Country  Max Temp Current Descriptions      Lat       Lng  \
# 0        Kapaa      US     75.52     scattered clouds  22.0752 -159.3190
# 2      Yeppoon      AU     83.98     scattered clouds -23.1333  150.7333
# 4       Castro      BR     61.57        broken clouds -24.7911  -50.0119
# 5      Isangel      VU     84.31        broken clouds -19.5500  169.2667
# 13      Yulara      AU     86.99      overcast clouds -25.2406  130.9889
# ..         ...     ...       ...                  ...      ...       ...
# 715  Rivadavia      AR     60.15            clear sky -33.1905  -68.4608
# 718      Jatai      BR     67.77     scattered clouds -17.8814  -51.7144
# 719      Babai      IN     88.47      overcast clouds  22.7000   77.9333
# 720   Itaituba      BR     70.93      overcast clouds  -4.2761  -55.9836
# 722    Ardakan      IR     77.34        broken clouds  32.3100   54.0175
#
#                         Hotel_Name
# 0                  Pono Kai Resort
# 2            Blossom's on Seaspray
# 4             Hotel Central Palace
# 5                      Tanna Lodge
# 13   Outback Pioneer Hotel & Lodge
# ..                             ...
# 715                 Hotel Pasambay
# 718                Hotel Rio Claro
# 719                    osho ashram
# 720                       TG Hotel
# 722    هتل رستوران باغ سرای اردکان
#
# [251 rows x 7 columns]

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
clean_hotel_df.to_csv("WeatherPy_vacation")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City"
)

# Display the map plot
hotel_map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\moore\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     229     try:
# --> 230         import cartopy.crs as ccrs
#     231         import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9464\1467159707.py in <module>
#       1 # Configure the map
# ----> 2 hotel_map = clean_hotel_df.hvplot.points(
#       3     "Lng",
#       4     "Lat",
#       5     geo = True,
#
# c:\Users\moore\anaconda3\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#    1188         to learn more about its parameters and options.
#    1189         """
# -> 1190         return self(x, y, kind="points", **kwds)
#    1191
#    1192     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# c:\Users\moore\anaconda3\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#     128                 return pn.panel(plot, **panel_dict)
#     129
# --> 130         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#     131
#     132     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# c:\Users\moore\anaconda3\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#     135         y = y or params.pop("y", None)
#     136         kind = kind or params.pop("kind", None)
# --> 137         return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#     138
#     139     def __dir__(self):
#
# c:\Users\moore\anaconda3\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394         self.dynamic = dynamic
#     395         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396         self.crs = self._process_crs(data, crs) if self.geo else None
#     397         self.project = project
#     398         self.coastline = coastline
#
# c:\Users\moore\anaconda3\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     643         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     644         try:
# --> 645             return process_crs(_crs)
#     646         except ValueError:
#     647             # only raise error if crs was specified in kwargs
#
# c:\Users\moore\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import pyproj
#     233     except ImportError:
# --> 234         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     235
#     236     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.
