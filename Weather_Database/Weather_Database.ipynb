# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 776

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

import traceback

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Descriptions": city_weather_desc})
        print(city_weather_desc)
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | kapaa
# scattered clouds
# Processing Record 3 of Set 1 | punta arenas
# scattered clouds
# Processing Record 4 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 1 | yeppoon
# scattered clouds
# Processing Record 6 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 1 | priiskovyy
# clear sky
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | castro
# broken clouds
# Processing Record 10 of Set 1 | isangel
# broken clouds
# Processing Record 11 of Set 1 | tasiilaq
# overcast clouds
# Processing Record 12 of Set 1 | busselton
# overcast clouds
# Processing Record 13 of Set 1 | srednekolymsk
# overcast clouds
# Processing Record 14 of Set 1 | nshamba
# overcast clouds
# Processing Record 15 of Set 1 | hermanus
# scattered clouds
# Processing Record 16 of Set 1 | hobart
# scattered clouds
# Processing Record 17 of Set 1 | pilikwe
# scattered clouds
# Processing Record 18 of Set 1 | yulara
# overcast clouds
# Processing Record 19 of Set 1 | avarua
# broken clouds
# Processing Record 20 of Set 1 | imbituba
# broken clouds
# Processing Record 21 of Set 1 | krasnoarmeysk
# overcast clouds
# Processing Record 22 of Set 1 | atuona
# clear sky
# Processing Record 23 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 1 | saskylakh
# overcast clouds
# Processing Record 25 of Set 1 | cherskiy
# overcast clouds
# Processing Record 26 of Set 1 | beringovskiy
# clear sky
# Processing Record 27 of Set 1 | hilo
# moderate rain
# Processing Record 28 of Set 1 | rio grande
# overcast clouds
# Processing Record 29 of Set 1 | albany
# scattered clouds
# Processing Record 30 of Set 1 | ponta do sol
# clear sky
# Processing Record 31 of Set 1 | vaini
# broken clouds
# Processing Record 32 of Set 1 | ewa beach
# clear sky
# Processing Record 33 of Set 1 | port blair
# scattered clouds
# Processing Record 34 of Set 1 | ribeira grande
# overcast clouds
# Processing Record 35 of Set 1 | jamestown
# broken clouds
# Processing Record 36 of Set 1 | kailua
# light rain
# Processing Record 37 of Set 1 | rikitea
# scattered clouds
# Processing Record 38 of Set 1 | port elizabeth
# clear sky
# Processing Record 39 of Set 1 | port-de-paix
# City not found. Skipping...
# Processing Record 40 of Set 1 | sao joao da barra
# overcast clouds
# Processing Record 41 of Set 1 | bengkulu
# overcast clouds
# Processing Record 42 of Set 1 | mataura
# few clouds
# Processing Record 43 of Set 1 | barrow
# light snow
# Processing Record 44 of Set 1 | ponta delgada
# fog
# Processing Record 45 of Set 1 | severo-kurilsk
# clear sky
# Processing Record 46 of Set 1 | turukhansk
# overcast clouds
# Processing Record 47 of Set 1 | sigli
# broken clouds
# Processing Record 48 of Set 1 | resistencia
# clear sky
# Processing Record 49 of Set 1 | flin flon
# overcast clouds
# Processing Record 50 of Set 1 | fairbanks
# broken clouds
# Processing Record 1 of Set 2 | grand gaube
# light rain
# Processing Record 2 of Set 2 | tiksi
# broken clouds
# Processing Record 3 of Set 2 | kaitangata
# scattered clouds
# Processing Record 4 of Set 2 | tortona
# overcast clouds
# Processing Record 5 of Set 2 | cumra
# clear sky
# Processing Record 6 of Set 2 | saint george
# clear sky
# Processing Record 7 of Set 2 | haines junction
# light snow
# Processing Record 8 of Set 2 | ushuaia
# clear sky
# Processing Record 9 of Set 2 | bluff
# scattered clouds
# Processing Record 10 of Set 2 | iralaya
# clear sky
# Processing Record 11 of Set 2 | carnarvon
# overcast clouds
# Processing Record 12 of Set 2 | itapirapua
# clear sky
# Processing Record 13 of Set 2 | georgetown
# scattered clouds
# Processing Record 14 of Set 2 | moranbah
# scattered clouds
# Processing Record 15 of Set 2 | kalashnikovo
# clear sky
# Processing Record 16 of Set 2 | bethel
# clear sky
# Processing Record 17 of Set 2 | quatre cocos
# light rain
# Processing Record 18 of Set 2 | tocopilla
# broken clouds
# Processing Record 19 of Set 2 | emerald
# few clouds
# Processing Record 20 of Set 2 | chabahar
# clear sky
# Processing Record 21 of Set 2 | mount gambier
# overcast clouds
# Processing Record 22 of Set 2 | meulaboh
# overcast clouds
# Processing Record 23 of Set 2 | am timan
# broken clouds
# Processing Record 24 of Set 2 | hearst
# scattered clouds
# Processing Record 25 of Set 2 | labelle
# clear sky
# Processing Record 26 of Set 2 | sasaima
# broken clouds
# Processing Record 27 of Set 2 | gualaquiza
# overcast clouds
# Processing Record 28 of Set 2 | caravelas
# scattered clouds
# Processing Record 29 of Set 2 | znamenskoye
# clear sky
# Processing Record 30 of Set 2 | zyryanovsk
# broken clouds
# Processing Record 31 of Set 2 | lavrentiya
# overcast clouds
# Processing Record 32 of Set 2 | la ronge
# scattered clouds
# Processing Record 33 of Set 2 | axim
# overcast clouds
# Processing Record 34 of Set 2 | spanish fork
# overcast clouds
# Processing Record 35 of Set 2 | kavaratti
# overcast clouds
# Processing Record 36 of Set 2 | saint-philippe
# scattered clouds
# Processing Record 37 of Set 2 | teya
# overcast clouds
# Processing Record 38 of Set 2 | clyde river
# light snow
# Processing Record 39 of Set 2 | astoria
# light rain
# Processing Record 40 of Set 2 | vila franca do campo
# overcast clouds
# Processing Record 41 of Set 2 | tuktoyaktuk
# clear sky
# Processing Record 42 of Set 2 | ahipara
# overcast clouds
# Processing Record 43 of Set 2 | havre-saint-pierre
# light snow
# Processing Record 44 of Set 2 | kruisfontein
# clear sky
# Processing Record 45 of Set 2 | hun
# clear sky
# Processing Record 46 of Set 2 | puerto ayora
# scattered clouds
# Processing Record 47 of Set 2 | sao filipe
# broken clouds
# Processing Record 48 of Set 2 | puerto escondido
# broken clouds
# Processing Record 49 of Set 2 | cape town
# clear sky
# Processing Record 50 of Set 2 | sola
# scattered clouds
# Processing Record 1 of Set 3 | ilulissat
# clear sky
# Processing Record 2 of Set 3 | kortkeros
# light rain
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | dubbo
# scattered clouds
# Processing Record 5 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 3 | arraial do cabo
# overcast clouds
# Processing Record 7 of Set 3 | zhanakorgan
# clear sky
# Processing Record 8 of Set 3 | chokurdakh
# overcast clouds
# Processing Record 9 of Set 3 | mahebourg
# light rain
# Processing Record 10 of Set 3 | lompoc
# clear sky
# Processing Record 11 of Set 3 | uvira
# light rain
# Processing Record 12 of Set 3 | cacaotepec
# scattered clouds
# Processing Record 13 of Set 3 | geraldton
# clear sky
# Processing Record 14 of Set 3 | guhagar
# scattered clouds
# Processing Record 15 of Set 3 | port alfred
# broken clouds
# Processing Record 16 of Set 3 | upernavik
# few clouds
# Processing Record 17 of Set 3 | sangar
# overcast clouds
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | los llanos de aridane
# clear sky
# Processing Record 20 of Set 3 | khatanga
# overcast clouds
# Processing Record 21 of Set 3 | henties bay
# scattered clouds
# Processing Record 22 of Set 3 | chapais
# overcast clouds
# Processing Record 23 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 3 | jardim
# clear sky
# Processing Record 25 of Set 3 | port hardy
# broken clouds
# Processing Record 26 of Set 3 | kodiak
# few clouds
# Processing Record 27 of Set 3 | sao joaquim do monte
# scattered clouds
# Processing Record 28 of Set 3 | jackson
# overcast clouds
# Processing Record 29 of Set 3 | singarayakonda
# scattered clouds
# Processing Record 30 of Set 3 | east london
# clear sky
# Processing Record 31 of Set 3 | laguna
# scattered clouds
# Processing Record 32 of Set 3 | asenovgrad
# overcast clouds
# Processing Record 33 of Set 3 | sosua
# light rain
# Processing Record 34 of Set 3 | ust-nera
# light snow
# Processing Record 35 of Set 3 | trelew
# few clouds
# Processing Record 36 of Set 3 | nemuro
# moderate rain
# Processing Record 37 of Set 3 | bredasdorp
# scattered clouds
# Processing Record 38 of Set 3 | lasa
# overcast clouds
# Processing Record 39 of Set 3 | coahuayana
# overcast clouds
# Processing Record 40 of Set 3 | santa marta
# few clouds
# Processing Record 41 of Set 3 | mugur-aksy
# overcast clouds
# Processing Record 42 of Set 3 | san pedro
# few clouds
# Processing Record 43 of Set 3 | lebu
# scattered clouds
# Processing Record 44 of Set 3 | severo-yeniseyskiy
# overcast clouds
# Processing Record 45 of Set 3 | hit
# overcast clouds
# Processing Record 46 of Set 3 | lamidan
# City not found. Skipping...
# Processing Record 47 of Set 3 | colares
# broken clouds
# Processing Record 48 of Set 3 | yar-sale
# overcast clouds
# Processing Record 49 of Set 3 | zarubino
# clear sky
# Processing Record 50 of Set 3 | quevedo
# overcast clouds
# Processing Record 1 of Set 4 | cidreira
# broken clouds
# Processing Record 2 of Set 4 | bambous virieux
# light rain
# Processing Record 3 of Set 4 | udgir
# broken clouds
# Processing Record 4 of Set 4 | yerbogachen
# overcast clouds
# Processing Record 5 of Set 4 | nanchong
# overcast clouds
# Processing Record 6 of Set 4 | boa vista
# broken clouds
# Processing Record 7 of Set 4 | novopavlovka
# overcast clouds
# Processing Record 8 of Set 4 | roald
# clear sky
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | mehamn
# clear sky
# Processing Record 11 of Set 4 | udachnyy
# overcast clouds
# Processing Record 12 of Set 4 | matay
# clear sky
# Processing Record 13 of Set 4 | airai
# light rain
# Processing Record 14 of Set 4 | suao
# City not found. Skipping...
# Processing Record 15 of Set 4 | thompson
# broken clouds
# Processing Record 16 of Set 4 | north bend
# overcast clouds
# Processing Record 17 of Set 4 | qaanaaq
# clear sky
# Processing Record 18 of Set 4 | macenta
# light rain
# Processing Record 19 of Set 4 | leningradskiy
# broken clouds
# Processing Record 20 of Set 4 | dikson
# overcast clouds
# Processing Record 21 of Set 4 | mar del plata
# clear sky
# Processing Record 22 of Set 4 | sinnamary
# broken clouds
# Processing Record 23 of Set 4 | nobeoka
# overcast clouds
# Processing Record 24 of Set 4 | shache
# overcast clouds
# Processing Record 25 of Set 4 | esperance
# scattered clouds
# Processing Record 26 of Set 4 | norman wells
# broken clouds
# Processing Record 27 of Set 4 | brownwood
# overcast clouds
# Processing Record 28 of Set 4 | corinto
# overcast clouds
# Processing Record 29 of Set 4 | sorland
# scattered clouds
# Processing Record 30 of Set 4 | vestmanna
# overcast clouds
# Processing Record 31 of Set 4 | north platte
# few clouds
# Processing Record 32 of Set 4 | maracas
# clear sky
# Processing Record 33 of Set 4 | vega de alatorre
# overcast clouds
# Processing Record 34 of Set 4 | nikolskoye
# overcast clouds
# Processing Record 35 of Set 4 | genhe
# few clouds
# Processing Record 36 of Set 4 | kushiro
# light intensity shower rain
# Processing Record 37 of Set 4 | tawau
# overcast clouds
# Processing Record 38 of Set 4 | novyy urgal
# clear sky
# Processing Record 39 of Set 4 | iqaluit
# light snow
# Processing Record 40 of Set 4 | namibe
# overcast clouds
# Processing Record 41 of Set 4 | zaraza
# scattered clouds
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | san cristobal
# broken clouds
# Processing Record 44 of Set 4 | elko
# overcast clouds
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | ostrovnoy
# few clouds
# Processing Record 47 of Set 4 | nouadhibou
# clear sky
# Processing Record 48 of Set 4 | artesia
# clear sky
# Processing Record 49 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 4 | santa isabel do rio negro
# light rain
# Processing Record 1 of Set 5 | ust-kuyga
# overcast clouds
# Processing Record 2 of Set 5 | cockburn town
# clear sky
# Processing Record 3 of Set 5 | lorengau
# overcast clouds
# Processing Record 4 of Set 5 | shunyi
# clear sky
# Processing Record 5 of Set 5 | tuatapere
# scattered clouds
# Processing Record 6 of Set 5 | ndele
# overcast clouds
# Processing Record 7 of Set 5 | magdagachi
# overcast clouds
# Processing Record 8 of Set 5 | inverness
# fog
# Processing Record 9 of Set 5 | coquimbo
# clear sky
# Processing Record 10 of Set 5 | anadyr
# clear sky
# Processing Record 11 of Set 5 | qaqortoq
# clear sky
# Processing Record 12 of Set 5 | curup
# light rain
# Processing Record 13 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 5 | butaritari
# light rain
# Processing Record 15 of Set 5 | cadiz
# overcast clouds
# Processing Record 16 of Set 5 | exeter
# moderate rain
# Processing Record 17 of Set 5 | verkhoyansk
# overcast clouds
# Processing Record 18 of Set 5 | calama
# clear sky
# Processing Record 19 of Set 5 | new norfolk
# broken clouds
# Processing Record 20 of Set 5 | torbay
# fog
# Processing Record 21 of Set 5 | phan thiet
# overcast clouds
# Processing Record 22 of Set 5 | pevek
# overcast clouds
# Processing Record 23 of Set 5 | dingle
# scattered clouds
# Processing Record 24 of Set 5 | ancud
# overcast clouds
# Processing Record 25 of Set 5 | kenora
# clear sky
# Processing Record 26 of Set 5 | te anau
# few clouds
# Processing Record 27 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 5 | egvekinot
# scattered clouds
# Processing Record 29 of Set 5 | klyuchi
# scattered clouds
# Processing Record 30 of Set 5 | invermere
# broken clouds
# Processing Record 31 of Set 5 | assiniboia
# overcast clouds
# Processing Record 32 of Set 5 | vysokogornyy
# overcast clouds
# Processing Record 33 of Set 5 | cochrane
# clear sky
# Processing Record 34 of Set 5 | hithadhoo
# scattered clouds
# Processing Record 35 of Set 5 | lichinga
# light intensity drizzle
# Processing Record 36 of Set 5 | hokitika
# overcast clouds
# Processing Record 37 of Set 5 | kremze
# broken clouds
# Processing Record 38 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 5 | santa vitoria do palmar
# broken clouds
# Processing Record 40 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 5 | la tuque
# broken clouds
# Processing Record 42 of Set 5 | saint-augustin
# broken clouds
# Processing Record 43 of Set 5 | yellowknife
# broken clouds
# Processing Record 44 of Set 5 | vao
# scattered clouds
# Processing Record 45 of Set 5 | kijang
# clear sky
# Processing Record 46 of Set 5 | chuy
# overcast clouds
# Processing Record 47 of Set 5 | naryan-mar
# light snow
# Processing Record 48 of Set 5 | talnakh
# overcast clouds
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 5 | ziro
# broken clouds
# Processing Record 1 of Set 6 | hasaki
# moderate rain
# Processing Record 2 of Set 6 | bac lieu
# scattered clouds
# Processing Record 3 of Set 6 | say
# broken clouds
# Processing Record 4 of Set 6 | kyra
# scattered clouds
# Processing Record 5 of Set 6 | san joaquin
# clear sky
# Processing Record 6 of Set 6 | marawi
# moderate rain
# Processing Record 7 of Set 6 | peniche
# overcast clouds
# Processing Record 8 of Set 6 | wahpeton
# overcast clouds
# Processing Record 9 of Set 6 | noumea
# few clouds
# Processing Record 10 of Set 6 | amapa
# broken clouds
# Processing Record 11 of Set 6 | voru
# overcast clouds
# Processing Record 12 of Set 6 | luderitz
# clear sky
# Processing Record 13 of Set 6 | takoradi
# overcast clouds
# Processing Record 14 of Set 6 | steamboat springs
# light snow
# Processing Record 15 of Set 6 | provideniya
# clear sky
# Processing Record 16 of Set 6 | cap-aux-meules
# overcast clouds
# Processing Record 17 of Set 6 | korla
# overcast clouds
# Processing Record 18 of Set 6 | dongsheng
# broken clouds
# Processing Record 19 of Set 6 | fortuna
# overcast clouds
# Processing Record 20 of Set 6 | klokkarvik
# City not found. Skipping...
# Processing Record 21 of Set 6 | hamilton
# overcast clouds
# Processing Record 22 of Set 6 | okhotsk
# overcast clouds
# Processing Record 23 of Set 6 | daru
# overcast clouds
# Processing Record 24 of Set 6 | tessalit
# clear sky
# Processing Record 25 of Set 6 | warmbad
# clear sky
# Processing Record 26 of Set 6 | husavik
# overcast clouds
# Processing Record 27 of Set 6 | tall kayf
# broken clouds
# Processing Record 28 of Set 6 | jodar
# overcast clouds
# Processing Record 29 of Set 6 | mankera
# overcast clouds
# Processing Record 30 of Set 6 | mahanoro
# light rain
# Processing Record 31 of Set 6 | westport
# clear sky
# Processing Record 32 of Set 6 | buzmeyin
# few clouds
# Processing Record 33 of Set 6 | bara
# broken clouds
# Processing Record 34 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 6 | ulaangom
# broken clouds
# Processing Record 36 of Set 6 | faanui
# scattered clouds
# Processing Record 37 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 6 | rabo de peixe
# fog
# Processing Record 39 of Set 6 | nanortalik
# clear sky
# Processing Record 40 of Set 6 | sheopur
# clear sky
# Processing Record 41 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 6 | ozu
# overcast clouds
# Processing Record 43 of Set 6 | lata
# overcast clouds
# Processing Record 44 of Set 6 | mwinilunga
# moderate rain
# Processing Record 45 of Set 6 | barao de melgaco
# broken clouds
# Processing Record 46 of Set 6 | chake chake
# broken clouds
# Processing Record 47 of Set 6 | souillac
# scattered clouds
# Processing Record 48 of Set 6 | zhigansk
# overcast clouds
# Processing Record 49 of Set 6 | luganville
# heavy intensity rain
# Processing Record 50 of Set 6 | gonen
# broken clouds
# Processing Record 1 of Set 7 | shenjiamen
# overcast clouds
# Processing Record 2 of Set 7 | derzhavinsk
# clear sky
# Processing Record 3 of Set 7 | port augusta
# overcast clouds
# Processing Record 4 of Set 7 | sri aman
# scattered clouds
# Processing Record 5 of Set 7 | lerwick
# overcast clouds
# Processing Record 6 of Set 7 | strezhevoy
# few clouds
# Processing Record 7 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 7 | saint-pierre
# clear sky
# Processing Record 9 of Set 7 | vostok
# broken clouds
# Processing Record 10 of Set 7 | hinesville
# clear sky
# Processing Record 11 of Set 7 | coihueco
# scattered clouds
# Processing Record 12 of Set 7 | sioux city
# mist
# Processing Record 13 of Set 7 | sur
# clear sky
# Processing Record 14 of Set 7 | saint-francois
# clear sky
# Processing Record 15 of Set 7 | viedma
# broken clouds
# Processing Record 16 of Set 7 | tigil
# scattered clouds
# Processing Record 17 of Set 7 | kahului
# broken clouds
# Processing Record 18 of Set 7 | rio branco
# scattered clouds
# Processing Record 19 of Set 7 | taicheng
# overcast clouds
# Processing Record 20 of Set 7 | general pico
# scattered clouds
# Processing Record 21 of Set 7 | jerome
# overcast clouds
# Processing Record 22 of Set 7 | saldanha
# clear sky
# Processing Record 23 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 7 | adrar
# clear sky
# Processing Record 25 of Set 7 | concepcion del oro
# overcast clouds
# Processing Record 26 of Set 7 | artyom
# overcast clouds
# Processing Record 27 of Set 7 | moron
# broken clouds
# Processing Record 28 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 29 of Set 7 | belyy yar
# light shower snow
# Processing Record 30 of Set 7 | portland
# overcast clouds
# Processing Record 31 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 32 of Set 7 | hambantota
# scattered clouds
# Processing Record 33 of Set 7 | cabedelo
# broken clouds
# Processing Record 34 of Set 7 | saint anthony
# light rain
# Processing Record 35 of Set 7 | saint-georges
# clear sky
# Processing Record 36 of Set 7 | quijingue
# clear sky
# Processing Record 37 of Set 7 | noshiro
# broken clouds
# Processing Record 38 of Set 7 | kavieng
# light rain
# Processing Record 39 of Set 7 | riyadh
# few clouds
# Processing Record 40 of Set 7 | lungesti
# overcast clouds
# Processing Record 41 of Set 7 | ystad
# overcast clouds
# Processing Record 42 of Set 7 | baoro
# broken clouds
# Processing Record 43 of Set 7 | pitimbu
# broken clouds
# Processing Record 44 of Set 7 | slonim
# overcast clouds
# Processing Record 45 of Set 7 | montepuez
# light rain
# Processing Record 46 of Set 7 | acapulco
# scattered clouds
# Processing Record 47 of Set 7 | otjiwarongo
# clear sky
# Processing Record 48 of Set 7 | sabang
# overcast clouds
# Processing Record 49 of Set 7 | poum
# clear sky
# Processing Record 50 of Set 7 | green river
# broken clouds
# Processing Record 1 of Set 8 | khowst
# overcast clouds
# Processing Record 2 of Set 8 | huaura
# overcast clouds
# Processing Record 3 of Set 8 | camargo
# broken clouds
# Processing Record 4 of Set 8 | palm valley
# clear sky
# Processing Record 5 of Set 8 | san quintin
# clear sky
# Processing Record 6 of Set 8 | ankazoabo
# clear sky
# Processing Record 7 of Set 8 | sangmelima
# overcast clouds
# Processing Record 8 of Set 8 | yining
# overcast clouds
# Processing Record 9 of Set 8 | le francois
# few clouds
# Processing Record 10 of Set 8 | krasnousolskiy
# City not found. Skipping...
# Processing Record 11 of Set 8 | marsa matruh
# few clouds
# Processing Record 12 of Set 8 | jarvenpaa
# broken clouds
# Processing Record 13 of Set 8 | hazorasp
# few clouds
# Processing Record 14 of Set 8 | grindavik
# fog
# Processing Record 15 of Set 8 | gourcy
# clear sky
# Processing Record 16 of Set 8 | victoria
# overcast clouds
# Processing Record 17 of Set 8 | aksu
# broken clouds
# Processing Record 18 of Set 8 | tevaitoa
# scattered clouds
# Processing Record 19 of Set 8 | semnan
# scattered clouds
# Processing Record 20 of Set 8 | garissa
# broken clouds
# Processing Record 21 of Set 8 | muyuka
# light rain
# Processing Record 22 of Set 8 | kampot
# broken clouds
# Processing Record 23 of Set 8 | shenzhen
# overcast clouds
# Processing Record 24 of Set 8 | byron bay
# overcast clouds
# Processing Record 25 of Set 8 | maragogi
# broken clouds
# Processing Record 26 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 8 | wollongong
# scattered clouds
# Processing Record 28 of Set 8 | neijiang
# overcast clouds
# Processing Record 29 of Set 8 | rundu
# scattered clouds
# Processing Record 30 of Set 8 | tautira
# scattered clouds
# Processing Record 31 of Set 8 | yuncheng
# clear sky
# Processing Record 32 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 8 | magadan
# overcast clouds
# Processing Record 34 of Set 8 | adilcevaz
# snow
# Processing Record 35 of Set 8 | marfino
# broken clouds
# Processing Record 36 of Set 8 | pacific grove
# clear sky
# Processing Record 37 of Set 8 | flinders
# scattered clouds
# Processing Record 38 of Set 8 | rovereto
# overcast clouds
# Processing Record 39 of Set 8 | bela
# overcast clouds
# Processing Record 40 of Set 8 | dudinka
# overcast clouds
# Processing Record 41 of Set 8 | nipawin
# overcast clouds
# Processing Record 42 of Set 8 | biak
# overcast clouds
# Processing Record 43 of Set 8 | san patricio
# overcast clouds
# Processing Record 44 of Set 8 | longyearbyen
# light snow
# Processing Record 45 of Set 8 | dunedin
# scattered clouds
# Processing Record 46 of Set 8 | kloulklubed
# overcast clouds
# Processing Record 47 of Set 8 | sao jose da coroa grande
# broken clouds
# Processing Record 48 of Set 8 | karatau
# clear sky
# Processing Record 49 of Set 8 | constitucion
# clear sky
# Processing Record 50 of Set 8 | valley
# light snow
# Processing Record 1 of Set 9 | pombas
# clear sky
# Processing Record 2 of Set 9 | avera
# clear sky
# Processing Record 3 of Set 9 | sitka
# light rain
# Processing Record 4 of Set 9 | kurumkan
# broken clouds
# Processing Record 5 of Set 9 | san andres
# broken clouds
# Processing Record 6 of Set 9 | menongue
# overcast clouds
# Processing Record 7 of Set 9 | umm lajj
# clear sky
# Processing Record 8 of Set 9 | lulea
# clear sky
# Processing Record 9 of Set 9 | ternate
# light rain
# Processing Record 10 of Set 9 | marzuq
# broken clouds
# Processing Record 11 of Set 9 | varadero
# clear sky
# Processing Record 12 of Set 9 | lakatoro
# overcast clouds
# Processing Record 13 of Set 9 | kuzedeyevo
# light snow
# Processing Record 14 of Set 9 | zhuhai
# scattered clouds
# Processing Record 15 of Set 9 | ermelo
# overcast clouds
# Processing Record 16 of Set 9 | aswan
# few clouds
# Processing Record 17 of Set 9 | ashcroft
# overcast clouds
# Processing Record 18 of Set 9 | danjiangkou
# overcast clouds
# Processing Record 19 of Set 9 | rehoboth
# clear sky
# Processing Record 20 of Set 9 | seddon
# light intensity shower rain
# Processing Record 21 of Set 9 | hovd
# clear sky
# Processing Record 22 of Set 9 | mazatlan
# broken clouds
# Processing Record 23 of Set 9 | vilhena
# overcast clouds
# Processing Record 24 of Set 9 | bud
# moderate rain
# Processing Record 25 of Set 9 | komsomolskiy
# overcast clouds
# Processing Record 26 of Set 9 | kasane
# scattered clouds
# Processing Record 27 of Set 9 | manzil jamil
# City not found. Skipping...
# Processing Record 28 of Set 9 | leshukonskoye
# light snow
# Processing Record 29 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 9 | praia da vitoria
# scattered clouds
# Processing Record 31 of Set 9 | goderich
# moderate rain
# Processing Record 32 of Set 9 | ballina
# overcast clouds
# Processing Record 33 of Set 9 | boca do acre
# broken clouds
# Processing Record 34 of Set 9 | qabis
# City not found. Skipping...
# Processing Record 35 of Set 9 | yaan
# overcast clouds
# Processing Record 36 of Set 9 | paranavai
# few clouds
# Processing Record 37 of Set 9 | bambanglipuro
# overcast clouds
# Processing Record 38 of Set 9 | kirakira
# overcast clouds
# Processing Record 39 of Set 9 | naze
# broken clouds
# Processing Record 40 of Set 9 | mizdah
# clear sky
# Processing Record 41 of Set 9 | fairview
# clear sky
# Processing Record 42 of Set 9 | lere
# scattered clouds
# Processing Record 43 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 9 | port moresby
# haze
# Processing Record 45 of Set 9 | ketchikan
# light rain
# Processing Record 46 of Set 9 | gizo
# broken clouds
# Processing Record 47 of Set 9 | dukhovshchina
# few clouds
# Processing Record 48 of Set 9 | bolshaya sosnova
# overcast clouds
# Processing Record 49 of Set 9 | klaksvik
# light rain
# Processing Record 50 of Set 9 | kouango
# overcast clouds
# Processing Record 1 of Set 10 | gorontalo
# overcast clouds
# Processing Record 2 of Set 10 | poli
# light rain
# Processing Record 3 of Set 10 | fare
# broken clouds
# Processing Record 4 of Set 10 | bontang
# overcast clouds
# Processing Record 5 of Set 10 | comodoro rivadavia
# clear sky
# Processing Record 6 of Set 10 | honningsvag
# light snow
# Processing Record 7 of Set 10 | pisco
# clear sky
# Processing Record 8 of Set 10 | skibbereen
# overcast clouds
# Processing Record 9 of Set 10 | cairns
# scattered clouds
# Processing Record 10 of Set 10 | simpang
# overcast clouds
# Processing Record 11 of Set 10 | palana
# broken clouds
# Processing Record 12 of Set 10 | nisia floresta
# light rain
# Processing Record 13 of Set 10 | jadu
# clear sky
# Processing Record 14 of Set 10 | fengzhen
# overcast clouds
# Processing Record 15 of Set 10 | batagay-alyta
# overcast clouds
# Processing Record 16 of Set 10 | kibala
# scattered clouds
# Processing Record 17 of Set 10 | guerrero negro
# clear sky
# Processing Record 18 of Set 10 | codajas
# light rain
# Processing Record 19 of Set 10 | coihaique
# clear sky
# Processing Record 20 of Set 10 | laurel
# clear sky
# Processing Record 21 of Set 10 | baykit
# overcast clouds
# Processing Record 22 of Set 10 | asmara
# broken clouds
# Processing Record 23 of Set 10 | lengshuitan
# few clouds
# Processing Record 24 of Set 10 | paoua
# overcast clouds
# Processing Record 25 of Set 10 | araouane
# clear sky
# Processing Record 26 of Set 10 | mandawar
# overcast clouds
# Processing Record 27 of Set 10 | ostersund
# clear sky
# Processing Record 28 of Set 10 | olinda
# scattered clouds
# Processing Record 29 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 30 of Set 10 | rawson
# few clouds
# Processing Record 31 of Set 10 | sorong
# broken clouds
# Processing Record 32 of Set 10 | hami
# overcast clouds
# Processing Record 33 of Set 10 | huarmey
# broken clouds
# Processing Record 34 of Set 10 | samur
# overcast clouds
# Processing Record 35 of Set 10 | priyutnoye
# clear sky
# Processing Record 36 of Set 10 | springbok
# clear sky
# Processing Record 37 of Set 10 | taksimo
# overcast clouds
# Processing Record 38 of Set 10 | bathsheba
# scattered clouds
# Processing Record 39 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 40 of Set 10 | pokhara
# light rain
# Processing Record 41 of Set 10 | cartagena del chaira
# overcast clouds
# Processing Record 42 of Set 10 | atar
# scattered clouds
# Processing Record 43 of Set 10 | tevriz
# few clouds
# Processing Record 44 of Set 10 | sept-iles
# light snow
# Processing Record 45 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 10 | brae
# overcast clouds
# Processing Record 47 of Set 10 | turek
# few clouds
# Processing Record 48 of Set 10 | ekibastuz
# clear sky
# Processing Record 49 of Set 10 | grenfell
# scattered clouds
# Processing Record 50 of Set 10 | the valley
# clear sky
# Processing Record 1 of Set 11 | ardesen
# light rain
# Processing Record 2 of Set 11 | grand bend
# light snow
# Processing Record 3 of Set 11 | maarianhamina
# clear sky
# Processing Record 4 of Set 11 | mopipi
# clear sky
# Processing Record 5 of Set 11 | eureka
# overcast clouds
# Processing Record 6 of Set 11 | vardo
# scattered clouds
# Processing Record 7 of Set 11 | narsaq
# clear sky
# Processing Record 8 of Set 11 | ibra
# clear sky
# Processing Record 9 of Set 11 | ubauro
# few clouds
# Processing Record 10 of Set 11 | harper
# broken clouds
# Processing Record 11 of Set 11 | hay river
# overcast clouds
# Processing Record 12 of Set 11 | prince george
# clear sky
# Processing Record 13 of Set 11 | sompeta
# clear sky
# Processing Record 14 of Set 11 | robe
# broken clouds
# Processing Record 15 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 11 | salalah
# clear sky
# Processing Record 17 of Set 11 | swift current
# clear sky
# Processing Record 18 of Set 11 | pangnirtung
# broken clouds
# Processing Record 19 of Set 11 | nyanza
# overcast clouds
# Processing Record 20 of Set 11 | dubti
# scattered clouds
# Processing Record 21 of Set 11 | mathathane
# scattered clouds
# Processing Record 22 of Set 11 | san jose
# few clouds
# Processing Record 23 of Set 11 | las cruces
# clear sky
# Processing Record 24 of Set 11 | bhubaneswar
# haze
# Processing Record 25 of Set 11 | gallatin
# mist
# Processing Record 26 of Set 11 | lagoa
# overcast clouds
# Processing Record 27 of Set 11 | kiama
# few clouds
# Processing Record 28 of Set 11 | oktyabrskiy
# overcast clouds
# Processing Record 29 of Set 11 | baruun-urt
# clear sky
# Processing Record 30 of Set 11 | vaitape
# scattered clouds
# Processing Record 31 of Set 11 | tecoanapa
# overcast clouds
# Processing Record 32 of Set 11 | eyl
# clear sky
# Processing Record 33 of Set 11 | vanimo
# overcast clouds
# Processing Record 34 of Set 11 | mustasaari
# clear sky
# Processing Record 35 of Set 11 | taltal
# scattered clouds
# Processing Record 36 of Set 11 | labuan
# few clouds
# Processing Record 37 of Set 11 | trabzon
# broken clouds
# Processing Record 38 of Set 11 | lavumisa
# overcast clouds
# Processing Record 39 of Set 11 | buxton
# light rain
# Processing Record 40 of Set 11 | huanren
# clear sky
# Processing Record 41 of Set 11 | roebourne
# few clouds
# Processing Record 42 of Set 11 | krasnoselkup
# scattered clouds
# Processing Record 43 of Set 11 | huntley
# moderate rain
# Processing Record 44 of Set 11 | ambilobe
# overcast clouds
# Processing Record 45 of Set 11 | nador
# clear sky
# Processing Record 46 of Set 11 | pimenta bueno
# broken clouds
# Processing Record 47 of Set 11 | aklavik
# broken clouds
# Processing Record 48 of Set 11 | bulungu
# overcast clouds
# Processing Record 49 of Set 11 | badaojiang
# City not found. Skipping...
# Processing Record 50 of Set 11 | khani
# overcast clouds
# Processing Record 1 of Set 12 | farah
# clear sky
# Processing Record 2 of Set 12 | brigantine
# broken clouds
# Processing Record 3 of Set 12 | tual
# overcast clouds
# Processing Record 4 of Set 12 | rafiganj
# overcast clouds
# Processing Record 5 of Set 12 | santiago del estero
# overcast clouds
# Processing Record 6 of Set 12 | san miguel
# clear sky
# Processing Record 7 of Set 12 | palauig
# scattered clouds
# Processing Record 8 of Set 12 | jaisalmer
# clear sky
# Processing Record 9 of Set 12 | lazarev
# overcast clouds
# Processing Record 10 of Set 12 | chaparral
# broken clouds
# Processing Record 11 of Set 12 | hirara
# broken clouds
# Processing Record 12 of Set 12 | khorramshahr
# broken clouds
# Processing Record 13 of Set 12 | sambava
# few clouds
# Processing Record 14 of Set 12 | inirida
# overcast clouds
# Processing Record 15 of Set 12 | great bend
# few clouds
# Processing Record 16 of Set 12 | faya
# few clouds
# Processing Record 17 of Set 12 | moen
# light shower snow
# Processing Record 18 of Set 12 | cleburne
# overcast clouds
# Processing Record 19 of Set 12 | salinas
# clear sky
# Processing Record 20 of Set 12 | puerto carreno
# overcast clouds
# Processing Record 21 of Set 12 | xam nua
# broken clouds
# Processing Record 22 of Set 12 | linhares
# broken clouds
# Processing Record 23 of Set 12 | sterling
# clear sky
# Processing Record 24 of Set 12 | northam
# overcast clouds
# Processing Record 25 of Set 12 | singaraja
# overcast clouds
# Processing Record 26 of Set 12 | wanaka
# broken clouds
# Processing Record 27 of Set 12 | northampton
# overcast clouds
# Processing Record 28 of Set 12 | dalvik
# overcast clouds
# Processing Record 29 of Set 12 | jiuquan
# clear sky
# Processing Record 30 of Set 12 | bubaque
# clear sky
# Processing Record 31 of Set 12 | codrington
# overcast clouds
# Processing Record 32 of Set 12 | jiaocheng
# overcast clouds
# Processing Record 33 of Set 12 | maun
# scattered clouds
# Processing Record 34 of Set 12 | ewo
# overcast clouds
# Processing Record 35 of Set 12 | carutapera
# overcast clouds
# Processing Record 36 of Set 12 | pak phanang
# scattered clouds
# Processing Record 37 of Set 12 | abu dhabi
# clear sky
# Processing Record 38 of Set 12 | nishihara
# broken clouds
# Processing Record 39 of Set 12 | nuuk
# clear sky
# Processing Record 40 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 12 | port hedland
# clear sky
# Processing Record 42 of Set 12 | darnah
# clear sky
# Processing Record 43 of Set 12 | mayumba
# overcast clouds
# Processing Record 44 of Set 12 | atambua
# light rain
# Processing Record 45 of Set 12 | kysyl-syr
# overcast clouds
# Processing Record 46 of Set 12 | vinh
# overcast clouds
# Processing Record 47 of Set 12 | dalnerechensk
# clear sky
# Processing Record 48 of Set 12 | pompeu
# scattered clouds
# Processing Record 49 of Set 12 | piney green
# clear sky
# Processing Record 50 of Set 12 | aripuana
# overcast clouds
# Processing Record 1 of Set 13 | gewane
# few clouds
# Processing Record 2 of Set 13 | vanavara
# overcast clouds
# Processing Record 3 of Set 13 | dzilam gonzalez
# clear sky
# Processing Record 4 of Set 13 | tuy hoa
# broken clouds
# Processing Record 5 of Set 13 | porto novo
# overcast clouds
# Processing Record 6 of Set 13 | walvis bay
# scattered clouds
# Processing Record 7 of Set 13 | tura
# overcast clouds
# Processing Record 8 of Set 13 | freeport
# clear sky
# Processing Record 9 of Set 13 | tuensang
# broken clouds
# Processing Record 10 of Set 13 | omboue
# broken clouds
# Processing Record 11 of Set 13 | kargasok
# overcast clouds
# Processing Record 12 of Set 13 | lucea
# clear sky
# Processing Record 13 of Set 13 | katwijk
# light rain
# Processing Record 14 of Set 13 | kutum
# overcast clouds
# Processing Record 15 of Set 13 | kamyshlov
# overcast clouds
# Processing Record 16 of Set 13 | partanna
# clear sky
# Processing Record 17 of Set 13 | rochegda
# few clouds
# Processing Record 18 of Set 13 | ambovombe
# broken clouds
# Processing Record 19 of Set 13 | auki
# overcast clouds
# Processing Record 20 of Set 13 | cortez
# light snow
# Processing Record 21 of Set 13 | cabo san lucas
# scattered clouds
# Processing Record 22 of Set 13 | ellisras
# scattered clouds
# Processing Record 23 of Set 13 | tarakan
# scattered clouds
# Processing Record 24 of Set 13 | bam
# clear sky
# Processing Record 25 of Set 13 | ibipeba
# clear sky
# Processing Record 26 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 13 | vila
# overcast clouds
# Processing Record 28 of Set 13 | kuusamo
# light snow
# Processing Record 29 of Set 13 | carndonagh
# overcast clouds
# Processing Record 30 of Set 13 | port saint lucie
# scattered clouds
# Processing Record 31 of Set 13 | coos bay
# overcast clouds
# Processing Record 32 of Set 13 | yuanping
# overcast clouds
# Processing Record 33 of Set 13 | kaputa
# light rain
# Processing Record 34 of Set 13 | rey bouba
# overcast clouds
# Processing Record 35 of Set 13 | grand-santi
# scattered clouds
# Processing Record 36 of Set 13 | varlamovo
# overcast clouds
# Processing Record 37 of Set 13 | vigrestad
# light rain
# Processing Record 38 of Set 13 | ixtapa
# clear sky
# Processing Record 39 of Set 13 | malpe
# scattered clouds
# Processing Record 40 of Set 13 | houffalize
# overcast clouds
# Processing Record 41 of Set 13 | noyon
# overcast clouds
# Processing Record 42 of Set 13 | belgrade
# clear sky
# Processing Record 43 of Set 13 | loandjili
# overcast clouds
# Processing Record 44 of Set 13 | pabna
# overcast clouds
# Processing Record 45 of Set 13 | micheweni
# scattered clouds
# Processing Record 46 of Set 13 | baijiantan
# clear sky
# Processing Record 47 of Set 13 | pyskowice
# clear sky
# Processing Record 48 of Set 13 | ushtobe
# clear sky
# Processing Record 49 of Set 13 | rio gallegos
# clear sky
# Processing Record 50 of Set 13 | namtsy
# overcast clouds
# Processing Record 1 of Set 14 | scottsbluff
# overcast clouds
# Processing Record 2 of Set 14 | fort-shevchenko
# overcast clouds
# Processing Record 3 of Set 14 | makat
# overcast clouds
# Processing Record 4 of Set 14 | lutkun
# light rain
# Processing Record 5 of Set 14 | padang
# overcast clouds
# Processing Record 6 of Set 14 | touros
# moderate rain
# Processing Record 7 of Set 14 | meiganga
# overcast clouds
# Processing Record 8 of Set 14 | akyab
# clear sky
# Processing Record 9 of Set 14 | gladstone
# clear sky
# Processing Record 10 of Set 14 | umm kaddadah
# broken clouds
# Processing Record 11 of Set 14 | minab
# overcast clouds
# Processing Record 12 of Set 14 | denpasar
# light rain
# Processing Record 13 of Set 14 | rabak
# overcast clouds
# Processing Record 14 of Set 14 | fukue
# clear sky
# Processing Record 15 of Set 14 | sawakin
# broken clouds
# Processing Record 16 of Set 14 | nsunga
# light rain
# Processing Record 17 of Set 14 | colquiri
# overcast clouds
# Processing Record 18 of Set 14 | akdepe
# overcast clouds
# Processing Record 19 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 14 | ippy
# overcast clouds
# Processing Record 21 of Set 14 | lima
# broken clouds
# Processing Record 22 of Set 14 | kichera
# snow
# Processing Record 23 of Set 14 | luba
# light rain
# Processing Record 24 of Set 14 | kagoro
# overcast clouds
# Processing Record 25 of Set 14 | aleksandrovsk
# overcast clouds
# Processing Record 26 of Set 14 | oranjemund
# clear sky
# Processing Record 27 of Set 14 | river falls
# snow
# Processing Record 28 of Set 14 | darhan
# few clouds
# Processing Record 29 of Set 14 | marovoay
# broken clouds
# Processing Record 30 of Set 14 | broome
# clear sky
# Processing Record 31 of Set 14 | karratha
# clear sky
# Processing Record 32 of Set 14 | bhatapara
# few clouds
# Processing Record 33 of Set 14 | rimouski
# overcast clouds
# Processing Record 34 of Set 14 | mana
# scattered clouds
# Processing Record 35 of Set 14 | waddan
# clear sky
# Processing Record 36 of Set 14 | urengoy
# scattered clouds
# Processing Record 37 of Set 14 | benton harbor
# overcast clouds
# Processing Record 38 of Set 14 | port hawkesbury
# light snow
# Processing Record 39 of Set 14 | coruripe
# overcast clouds
# Processing Record 40 of Set 14 | atasu
# clear sky
# Processing Record 41 of Set 14 | pangody
# overcast clouds
# Processing Record 42 of Set 14 | ozernovskiy
# clear sky
# Processing Record 43 of Set 14 | crixas
# clear sky
# Processing Record 44 of Set 14 | sampang
# moderate rain
# Processing Record 45 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 14 | syracuse
# overcast clouds
# Processing Record 47 of Set 14 | bilibino
# overcast clouds
# Processing Record 48 of Set 14 | luanda
# broken clouds
# Processing Record 49 of Set 14 | severnyy-kospashskiy
# overcast clouds
# Processing Record 50 of Set 14 | pokanayevka
# City not found. Skipping...
# Processing Record 1 of Set 15 | staritsa
# clear sky
# Processing Record 2 of Set 15 | gatton
# scattered clouds
# Processing Record 3 of Set 15 | honiara
# overcast clouds
# Processing Record 4 of Set 15 | verkh-usugli
# clear sky
# Processing Record 5 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 15 | quelimane
# overcast clouds
# Processing Record 7 of Set 15 | lajas
# clear sky
# Processing Record 8 of Set 15 | kaeo
# overcast clouds
# Processing Record 9 of Set 15 | namatanai
# light rain
# Processing Record 10 of Set 15 | wellington
# few clouds
# Processing Record 11 of Set 15 | smidovich
# clear sky
# Processing Record 12 of Set 15 | alyangula
# clear sky
# Processing Record 13 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 15 | nivala
# few clouds
# Processing Record 15 of Set 15 | port lincoln
# scattered clouds
# Processing Record 16 of Set 15 | naron
# overcast clouds
# Processing Record 17 of Set 15 | la ciotat
# overcast clouds
# Processing Record 18 of Set 15 | blythe
# clear sky
# Processing Record 19 of Set 15 | kholodnyy
# overcast clouds
# Processing Record 20 of Set 15 | manoel urbano
# overcast clouds
# Processing Record 21 of Set 15 | esmeraldas
# broken clouds
# Processing Record 22 of Set 15 | shimoni
# overcast clouds
# Processing Record 23 of Set 15 | kudahuvadhoo
# clear sky
# Processing Record 24 of Set 15 | appleton
# overcast clouds
# Processing Record 25 of Set 15 | port macquarie
# overcast clouds
# Processing Record 26 of Set 15 | pouembout
# overcast clouds
# Processing Record 27 of Set 15 | kiomboi
# clear sky
# Processing Record 28 of Set 15 | hirata
# few clouds
# Processing Record 29 of Set 15 | boksitogorsk
# overcast clouds
# Processing Record 30 of Set 15 | soto la marina
# broken clouds
# Processing Record 31 of Set 15 | oromocto
# light snow
# Processing Record 32 of Set 15 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 33 of Set 15 | middelburg
# overcast clouds
# Processing Record 34 of Set 15 | buin
# clear sky
# Processing Record 35 of Set 15 | valdivia
# overcast clouds
# Processing Record 36 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 15 | champerico
# clear sky
# Processing Record 38 of Set 15 | san policarpo
# scattered clouds
# Processing Record 39 of Set 15 | rapid valley
# snow
# Processing Record 40 of Set 15 | pochutla
# overcast clouds
# Processing Record 41 of Set 15 | santa rosa
# broken clouds
# Processing Record 42 of Set 15 | neuquen
# clear sky
# Processing Record 43 of Set 15 | moyale
# clear sky
# Processing Record 44 of Set 15 | mbanza-ngungu
# overcast clouds
# Processing Record 45 of Set 15 | kokopo
# moderate rain
# Processing Record 46 of Set 15 | parrita
# broken clouds
# Processing Record 47 of Set 15 | tamandare
# overcast clouds
# Processing Record 48 of Set 15 | old shinyanga
# scattered clouds
# Processing Record 49 of Set 15 | ninghai
# overcast clouds
# Processing Record 50 of Set 15 | veraval
# clear sky
# Processing Record 1 of Set 16 | tawzar
# City not found. Skipping...
# Processing Record 2 of Set 16 | leh
# overcast clouds
# Processing Record 3 of Set 16 | matara
# few clouds
# Processing Record 4 of Set 16 | khorinsk
# overcast clouds
# Processing Record 5 of Set 16 | altay
# scattered clouds
# Processing Record 6 of Set 16 | verkhnyaya inta
# overcast clouds
# Processing Record 7 of Set 16 | athabasca
# overcast clouds
# Processing Record 8 of Set 16 | selfoss
# light rain
# Processing Record 9 of Set 16 | rio verde de mato grosso
# clear sky
# Processing Record 10 of Set 16 | torrington
# scattered clouds
# Processing Record 11 of Set 16 | jishou
# light rain
# Processing Record 12 of Set 16 | alexandria
# clear sky
# Processing Record 13 of Set 16 | tahta
# clear sky
# Processing Record 14 of Set 16 | carros
# broken clouds
# Processing Record 15 of Set 16 | bayji
# overcast clouds
# Processing Record 16 of Set 16 | oyama
# overcast clouds
# Processing Record 17 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 16 | rivadavia
# clear sky
# Processing Record 19 of Set 16 | hatillo
# light rain
# Processing Record 20 of Set 16 | belmonte
# scattered clouds
# Processing Record 21 of Set 16 | jatai
# scattered clouds
# Processing Record 22 of Set 16 | babai
# overcast clouds
# Processing Record 23 of Set 16 | itaituba
# overcast clouds
# Processing Record 24 of Set 16 | college
# broken clouds
# Processing Record 25 of Set 16 | ardakan
# broken clouds
# Processing Record 26 of Set 16 | kamaishi
# scattered clouds
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 724

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Kapaa  22.0752 -159.3190     75.52        87          40
# 1   Punta Arenas -53.1500  -70.9167     42.91        70          40
# 2        Yeppoon -23.1333  150.7333     83.98        71          39
# 3     Priiskovyy  51.9333  116.6333     57.33        41           7
# 4         Castro -24.7911  -50.0119     61.57        93          55
# 5        Isangel -19.5500  169.2667     84.31        84          75
# 6       Tasiilaq  65.6145  -37.6368     24.96        75         100
# 7      Busselton -33.6500  115.3333     61.41        86         100
# 8  Srednekolymsk  67.4500  153.6833     27.34        84          97
# 9        Nshamba  -1.7983   31.5511     67.33        73          94
#
#    Wind Speed Country Current Descriptions
# 0        6.91      US     scattered clouds
# 1       17.27      CL     scattered clouds
# 2        9.51      AU     scattered clouds
# 3       12.71      RU            clear sky
# 4        1.72      BR        broken clouds
# 5        0.00      VU        broken clouds
# 6        6.35      GL      overcast clouds
# 7       16.37      AU      overcast clouds
# 8        4.32      RU      overcast clouds
# 9        1.83      TZ      overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Descriptions'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Descriptions"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_columns]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Kapaa      US  22.0752 -159.3190     75.52        87          40
# 1   Punta Arenas      CL -53.1500  -70.9167     42.91        70          40
# 2        Yeppoon      AU -23.1333  150.7333     83.98        71          39
# 3     Priiskovyy      RU  51.9333  116.6333     57.33        41           7
# 4         Castro      BR -24.7911  -50.0119     61.57        93          55
# 5        Isangel      VU -19.5500  169.2667     84.31        84          75
# 6       Tasiilaq      GL  65.6145  -37.6368     24.96        75         100
# 7      Busselton      AU -33.6500  115.3333     61.41        86         100
# 8  Srednekolymsk      RU  67.4500  153.6833     27.34        84          97
# 9        Nshamba      TZ  -1.7983   31.5511     67.33        73          94
#
#    Wind Speed Current Descriptions
# 0        6.91     scattered clouds
# 1       17.27     scattered clouds
# 2        9.51     scattered clouds
# 3       12.71            clear sky
# 4        1.72        broken clouds
# 5        0.00        broken clouds
# 6        6.35      overcast clouds
# 7       16.37      overcast clouds
# 8        4.32      overcast clouds
# 9        1.83      overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                     object
# Country                  object
# Lat                     float64
# Lng                     float64
# Max Temp                float64
# Humidity                  int64
# Cloudiness                int64
# Wind Speed              float64
# Current Descriptions     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv("WeatherPy_Database", index_label="City_ID")
